# %%
from langgraph.graph import StateGraph, START, END
from langchain_google_genai import ChatGoogleGenerativeAI
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()

model = ChatGoogleGenerativeAI(model= 'gemini-2.0-flash')

# %%
class Blogstate(TypedDict):
    title: str
    outline: str
    content: str

# %%
def create_outline(state: Blogstate)-> Blogstate:
    title= state['title']
    # call llm
    prompt = f'create an outline for a blog post with the title: {title}'
    outline = model.invoke(prompt).content
    
    state['outline'] = outline
    
    return state

# %%
def create_blog(state: Blogstate)-> Blogstate:
    outline = state['outline']
    title = state['title']
    #call llm
    prompt = f'write a detailed blog one the title: {title} using the outline: {outline}'
    
    content = model.invoke(prompt).content
    state['content'] = content
    
    return state

# %%
graph = StateGraph(Blogstate)

# nodes 
graph.add_node('create_outline',create_outline)
graph.add_node('create_blog',create_blog)

# edges
graph.add_edge(START,'create_outline')
graph.add_edge('create_outline','create_blog')
graph.add_edge('create_blog',END)

workflow = graph.compile()

# %%
intial_state = {'title': 'Rise of AI in India'}

final_state = workflow.invoke(intial_state)

print(final_state['content'])
# Out:
# ## Rise of AI in India: A Transformative Journey
#
# **I. Introduction (Capturing the Reader's Attention)**
#
# A. **Hook:** Imagine a farmer in rural Maharashtra, using a smartphone app powered by AI to predict the optimal time to irrigate his crops, increasing his yield by 30%. This isn't a futuristic fantasy; it's a glimpse into the rapidly evolving reality of Artificial Intelligence (AI) in India.
#
# B. **Briefly define AI:** In simple terms, AI refers to the ability of machines to perform tasks that typically require human intelligence, such as learning, problem-solving, and decision-making. It's about creating systems that can think and act like humans, but often with greater speed and efficiency.
#
# C. **Thesis Statement:** India is experiencing a significant surge in AI adoption, driven by factors like government initiatives, a skilled workforce, and a growing digital economy, presenting both opportunities and challenges that need careful navigation.
#
# D. **Briefly outline the key areas the blog post will cover:** This blog post will delve into the drivers behind India's AI boom, explore its applications across key sectors, address the challenges and concerns surrounding its implementation, and provide a future outlook on the transformative potential of AI in the country.
#
# **II. Drivers of AI Growth in India (Why is AI booming?)**
#
# A. **Government Initiatives & Policies:**
#
# *   **National Strategy for Artificial Intelligence (NITI Aayog):** The Indian government recognizes AI as a crucial driver of economic growth and social progress. NITI Aayog's National Strategy for AI focuses on developing a robust AI ecosystem, promoting research and development, and fostering ethical and responsible AI adoption. The strategy aims to position India as a global leader in AI.
# *   **Investment in AI research and development:** The government is actively investing in AI R&D through grants, funding for research institutions, and partnerships with the private sector. This investment is crucial for developing indigenous AI solutions and fostering innovation.
# *   **Policies promoting AI adoption across various sectors:** Specific policies are being implemented to encourage AI adoption in sectors like healthcare, agriculture, education, and smart cities. These policies include incentives, pilot projects, and regulatory frameworks that support AI deployment.
#
# B. **Skilled Workforce & Talent Pool:**
#
# *   **Growing number of STEM graduates:** India boasts a large pool of STEM (Science, Technology, Engineering, and Mathematics) graduates, providing a strong foundation for AI development. This talent pool is a significant advantage for India in the global AI landscape.
# *   **Availability of skilled engineers and data scientists:** The demand for AI professionals is rapidly increasing, and India is witnessing a growth in the number of skilled engineers and data scientists. These professionals are crucial for developing and implementing AI solutions across various industries.
# *   **Rise of AI-focused education and training programs:** Recognizing the skills gap, numerous universities and institutions are offering AI-focused courses, bootcamps, and training programs. These initiatives are helping to bridge the gap between the demand and supply of AI talent.
#
# C. **Digital Infrastructure & Data Availability:**
#
# *   **Expanding internet penetration and mobile usage:** India has witnessed a massive increase in internet penetration and mobile usage, creating a vast digital landscape. This provides a strong foundation for AI applications that rely on data and connectivity.
# *   **Increase in data generation and accessibility:** The increasing digitalization of various sectors has led to a surge in data generation. The availability of large datasets is crucial for training AI models and developing effective solutions.
# *   **Cloud computing infrastructure supporting AI development:** Cloud computing provides the necessary infrastructure for storing, processing, and analyzing large datasets required for AI development. The availability of affordable and scalable cloud services is driving AI adoption in India.
#
# D. **Growing Economy & Investment:**
#
# *   **Attractiveness for foreign investment in AI startups:** India's growing economy and large market size make it an attractive destination for foreign investment in AI startups. This investment is fueling innovation and accelerating the development of AI solutions.
# *   **Increased funding for AI research and development:** Both government and private sector organizations are increasing their funding for AI research and development. This investment is crucial for driving innovation and developing cutting-edge AI technologies.
# *   **Demand for AI solutions across various industries:** Businesses across various industries are recognizing the potential of AI to improve efficiency, reduce costs, and enhance customer experiences. This demand is driving the adoption of AI solutions and fueling the growth of the AI market in India.
#
# **III. AI Applications in Key Sectors (Where is AI being used?)**
#
# A. **Healthcare:**
#
# *   **AI-powered diagnostics and personalized medicine:** AI algorithms can analyze medical images, such as X-rays and MRIs, to detect diseases earlier and more accurately. Personalized medicine uses AI to tailor treatment plans based on individual patient characteristics.
# *   **Drug discovery and development:** AI can accelerate the drug discovery process by analyzing large datasets of chemical compounds and biological data. This can lead to the development of new and more effective drugs.
# *   **Remote patient monitoring:** AI-powered wearable devices and remote monitoring systems can track patients' vital signs and provide real-time alerts to healthcare providers. This can improve patient outcomes and reduce healthcare costs.
#
# B. **Agriculture:**
#
# *   **Precision farming and crop monitoring:** AI-powered drones and sensors can collect data on soil conditions, crop health, and weather patterns. This data can be used to optimize irrigation, fertilization, and pest control, leading to increased yields and reduced resource consumption.
# *   **AI-driven irrigation and pest control:** AI algorithms can analyze data on soil moisture, weather patterns, and pest infestations to automate irrigation and pest control systems. This can save water, reduce the use of pesticides, and improve crop health.
# *   **Supply chain optimization:** AI can optimize agricultural supply chains by predicting demand, managing inventory, and streamlining logistics. This can reduce waste, improve efficiency, and ensure that food reaches consumers in a timely manner.
#
# C. **Finance:**
#
# *   **Fraud detection and risk management:** AI algorithms can analyze financial transactions and identify patterns that indicate fraudulent activity. This can help financial institutions prevent fraud and reduce losses. AI is also used to assess credit risk and manage investment portfolios.
# *   **Algorithmic trading and investment analysis:** AI-powered trading algorithms can analyze market data and execute trades automatically, often at speeds that are impossible for humans. AI is also used to analyze investment opportunities and provide recommendations to investors.
# *   **Personalized banking and customer service:** AI-powered chatbots and virtual assistants can provide personalized customer service and answer customer inquiries. AI is also used to personalize banking products and services based on individual customer needs.
#
# D. **Education:**
#
# *   **Personalized learning platforms:** AI-powered learning platforms can adapt to individual student learning styles and provide personalized content and feedback. This can improve student engagement and learning outcomes.
# *   **Automated grading and feedback:** AI algorithms can automate the grading of assignments and provide students with immediate feedback. This can free up teachers' time and allow them to focus on more personalized instruction.
# *   **AI-powered tutoring systems:** AI-powered tutoring systems can provide students with personalized instruction and support in specific subjects. This can help students improve their understanding and performance.
#
# E. **Transportation:**
#
# *   **Traffic management and optimization:** AI algorithms can analyze traffic data and optimize traffic flow, reducing congestion and improving commute times. This can also reduce fuel consumption and emissions.
# *   **Autonomous vehicles (development and testing):** India is actively involved in the development and testing of autonomous vehicles. AI is the core technology behind autonomous driving, enabling vehicles to perceive their surroundings, navigate, and make decisions.
# *   **Logistics and supply chain efficiency:** AI can optimize logistics and supply chains by predicting demand, managing inventory, and streamlining transportation routes. This can reduce costs, improve efficiency, and ensure that goods reach their destinations on time.
#
# **IV. Challenges and Concerns (What are the hurdles?)**
#
# A. **Data Privacy and Security:**
#
# *   **Concerns about data collection and usage:** The use of AI often involves the collection and analysis of large amounts of personal data. This raises concerns about data privacy and security, as well as the potential for misuse of data.
# *   **Need for robust data protection regulations:** India needs to strengthen its data protection regulations to ensure that personal data is collected, used, and stored responsibly. This includes implementing measures to protect data from unauthorized access, use, or disclosure.
# *   **Addressing biases in AI algorithms:** AI algorithms can be biased if they are trained on biased data. This can lead to unfair or discriminatory outcomes. It is important to identify and address biases in AI algorithms to ensure that they are fair and equitable.
#
# B. **Ethical Considerations:**
#
# *   **Potential for job displacement:** The automation of tasks through AI can lead to job displacement in certain sectors. It is important to address this challenge by providing workers with training and support to transition to new roles.
# *   **Bias and fairness in AI systems:** AI systems can perpetuate and amplify existing biases in society. It is important to ensure that AI systems are designed and used in a way that promotes fairness and equity.
# *   **Transparency and accountability:** It is important to understand how AI systems make decisions and to hold those who develop and deploy them accountable for their actions. This requires transparency in AI development and deployment, as well as mechanisms for redress when AI systems cause harm.
#
# C. **Infrastructure Limitations:**
#
# *   **Uneven access to internet and computing resources:** Access to internet and computing resources is unevenly distributed across India. This can limit the adoption of AI in rural areas and among marginalized communities.
# *   **Need for improved digital literacy:** Many people in India lack the digital literacy skills needed to use and understand AI technologies. It is important to improve digital literacy through education and training programs.
# *   **Capacity building for AI adoption:** There is a need to build capacity for AI adoption across various sectors. This includes training professionals in AI skills, developing AI infrastructure, and creating a supportive regulatory environment.
#
# D. **Skills Gap:**
#
# *   **Demand for specialized AI skills outpacing supply:** The demand for specialized AI skills is growing rapidly, but the supply of qualified professionals is not keeping pace. This skills gap is a major challenge for India's AI ecosystem.
# *   **Need for upskilling and reskilling initiatives:** It is important to invest in upskilling and reskilling initiatives to train workers in AI skills. This includes providing training programs for existing workers, as well as developing new educational programs for students.
# *   **Attracting and retaining AI talent:** India needs to attract and retain AI talent to build a strong AI ecosystem. This includes offering competitive salaries and benefits, providing opportunities for professional development, and creating a supportive work environment.
#
# **V. Future Outlook (What's next for AI in India?)**
#
# A. **Predictions for AI growth and impact in the coming years:** The AI market in India is expected to grow rapidly in the coming years, driven by increasing adoption across various sectors. AI is expected to have a significant impact on the Indian economy and society, leading to increased productivity, improved efficiency, and new opportunities for innovation.
#
# B. **Emerging trends and technologies in AI (e.g., Edge AI, Generative AI):** Emerging trends in AI, such as Edge AI (processing data closer to the source) and Generative AI (creating new content), are expected to have a significant impact on India. Edge AI can enable real-time AI applications in areas with limited connectivity, while Generative AI can be used to create new products and services.
#
# C. **Potential for India to become a global AI hub:** India has the potential to become a global AI hub, given its large talent pool, growing economy, and supportive government policies. To realize this potential, India needs to address the challenges and concerns outlined above and continue to invest in AI research and development.
#
# D. **Importance of addressing the challenges to realize the full potential of AI:** Addressing the challenges related to data privacy, ethics, infrastructure, and skills is crucial for realizing the full potential of AI in India. A responsible and ethical approach to AI development and deployment is essential for ensuring that AI benefits all of society.
#
# **VI. Conclusion (Summarizing and Call to Action)**
#
# A. **Recap of the key points discussed in the blog post:** This blog post has explored the rise of AI in India, highlighting the drivers behind its growth, its applications across key sectors, the challenges and concerns surrounding its implementation, and the future outlook for AI in the country.
#
# B. **Reinforce the importance of AI for India's future:** AI has the potential to transform India's economy and society, leading to increased productivity, improved efficiency, and new opportunities for innovation. It is crucial for India to embrace AI and address the challenges to realize its full potential.
#
# C. **Call to action:** We encourage you to explore the world of AI, learn about its potential, and contribute to its responsible development and deployment. Explore online courses on platforms like Coursera and edX. Share your thoughts and experiences with AI in the comments below. Follow us for more updates on the exciting developments in AI in India.
#
# D. **Final thought-provoking statement about the transformative power of AI in India:** AI is not just a technology; it's a transformative force that has the power to reshape India's future, creating a more prosperous, equitable, and sustainable society. By embracing AI responsibly and ethically, India can unlock its immense potential and become a global leader in the age of artificial intelligence.

# %%
print(final_state['outline'])
# Out:
# ## Blog Post Outline: Rise of AI in India
#
# **Title: Rise of AI in India**
#
# **I. Introduction (Capturing the Reader's Attention)**
#     *   A. Hook: Start with a compelling statistic about AI adoption in India or a real-life example of AI impacting Indian lives.
#     *   B. Briefly define AI (Artificial Intelligence) in a layman's term.
#     *   C. Thesis Statement: India is experiencing a significant surge in AI adoption, driven by factors like government initiatives, a skilled workforce, and a growing digital economy, presenting both opportunities and challenges.
#     *   D. Briefly outline the key areas the blog post will cover.
#
# **II. Drivers of AI Growth in India (Why is AI booming?)**
#     *   A. **Government Initiatives & Policies:**
#         *   National Strategy for Artificial Intelligence (NITI Aayog) - Goals and objectives.
#         *   Investment in AI research and development.
#         *   Policies promoting AI adoption across various sectors.
#     *   B. **Skilled Workforce & Talent Pool:**
#         *   Growing number of STEM graduates.
#         *   Availability of skilled engineers and data scientists.
#         *   Rise of AI-focused education and training programs.
#     *   C. **Digital Infrastructure & Data Availability:**
#         *   Expanding internet penetration and mobile usage.
#         *   Increase in data generation and accessibility.
#         *   Cloud computing infrastructure supporting AI development.
#     *   D. **Growing Economy & Investment:**
#         *   Attractiveness for foreign investment in AI startups.
#         *   Increased funding for AI research and development.
#         *   Demand for AI solutions across various industries.
#
# **III. AI Applications in Key Sectors (Where is AI being used?)**
#     *   A. **Healthcare:**
#         *   AI-powered diagnostics and personalized medicine.
#         *   Drug discovery and development.
#         *   Remote patient monitoring.
#     *   B. **Agriculture:**
#         *   Precision farming and crop monitoring.
#         *   AI-driven irrigation and pest control.
#         *   Supply chain optimization.
#     *   C. **Finance:**
#         *   Fraud detection and risk management.
#         *   Algorithmic trading and investment analysis.
#         *   Personalized banking and customer service.
#     *   D. **Education:**
#         *   Personalized learning platforms.
#         *   Automated grading and feedback.
#         *   AI-powered tutoring systems.
#     *   E. **Transportation:**
#         *   Traffic management and optimization.
#         *   Autonomous vehicles (development and testing).
#         *   Logistics and supply chain efficiency.
#
# **IV. Challenges and Concerns (What are the hurdles?)**
#     *   A. **Data Privacy and Security:**
#         *   Concerns about data collection and usage.
#         *   Need for robust data protection regulations.
#         *   Addressing biases in AI algorithms.
#     *   B. **Ethical Considerations:**
#         *   Potential for job displacement.
#         *   Bias and fairness in AI systems.
#         *   Transparency and accountability.
#     *   C. **Infrastructure Limitations:**
#         *   Uneven access to internet and computing resources.
#         *   Need for improved digital literacy.
#         *   Capacity building for AI adoption.
#     *   D. **Skills Gap:**
#         *   Demand for specialized AI skills outpacing supply.
#         *   Need for upskilling and reskilling initiatives.
#         *   Attracting and retaining AI talent.
#
# **V. Future Outlook (What's next for AI in India?)**
#     *   A.  Predictions for AI growth and impact in the coming years.
#     *   B.  Emerging trends and technologies in AI (e.g., Edge AI, Generative AI).
#     *   C.  Potential for India to become a global AI hub.
#     *   D.  Importance of addressing the challenges to realize the full potential of AI.
#
# **VI. Conclusion (Summarizing and Call to Action)**
#     *   A.  Recap of the key points discussed in the blog post.
#     *   B.  Reinforce the importance of AI for India's future.
#     *   C.  Call to action: Encourage readers to engage with AI technology, learn about its potential, and contribute to responsible development and deployment.  (e.g., "Explore online courses," "Share your thoughts in the comments," "Follow us for more updates on AI in India.")
#     *   D.  Final thought-provoking statement about the transformative power of AI in India.
#
# **Optional Additions:**
#
# *   Include relevant images, videos, and infographics to enhance engagement.
# *   Cite sources and data to support claims.
# *   Consider featuring interviews with AI experts or entrepreneurs in India.
# *   Add a section on AI startups in India and their innovations.
